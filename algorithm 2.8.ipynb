# %%
s1='PyQt'

# %%
s1
# Out:
# 'PyQt'

# %%
s2="Python"

# %%
s2
# Out:
# 'Python'

# %%
s3='''Pemrograman GUI dengan Python dan PyQt'''

# %%
s3 '/nPemrograman GUI\ndengan Python dan PyQt\n'
# Out:
#   File "<ipython-input-12-3c99cb9a9bdd>", line 1
#     s3 '/nPemrograman GUI\ndengan Python dan PyQt\n'
#                                                    ^
# SyntaxError: invalid syntax

# %%
s4="""Pemrograman GUI dengan Python dan PyQt"""

# %%
s4
# Out:
# 'Pemrograman GUI dengan Python dan PyQt'

# %%
b='python'

# %%
b
# Out:
# 'python'

# %%
b=b . capitalize()

# %%
b
# Out:
# 'Python'

# %%
b=b . upper()

# %%
b
# Out:
# 'PYTHON'

# %%
b=b . lower()

# %%
b
# Out:
# 'python'

# %%
b . isupper()
# Out:
# False

# %%
b . islower()
# Out:
# True

# %%
s=' '.join(['saya','makan','ayam'])

# %%
s
# Out:
# 'saya makan ayam'

# %%
nim='16610o21'

# %%
nim . isnumeric()
# Out:
# False

# %%
nim='16610021'

# %%
nim . isnumeric()
# Out:
# True

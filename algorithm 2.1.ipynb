# %%
a=12345

# %%
type(a)
# Out:
# int

# %%
b=str(a)

# %%
b '12345'
# Out:
#   File "<ipython-input-8-658ff6a5aea3>", line 1
#     b '12345'
#             ^
# SyntaxError: invalid syntax

# %%
type(b)
# Out:
# str
